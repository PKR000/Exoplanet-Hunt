# %%
import os
import lightkurve as lk
import matplotlib.pyplot as plt
import glob

tic_id = 261136679
star_directory = f"TIC {tic_id}"
base_dir = os.path.join(os.getcwd(), "Downloaded data", star_directory)
fits_files = glob.glob(os.path.join(base_dir, '**', '*_lc.fits'), recursive=True)


lc = lk.read(fits_files[1])
print(type(lc))

if isinstance(lc, lk.lightcurve.TessLightCurve):
    print("lightcurve found.")
    lc.plot()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/preston/Desktop/Exoplanet-Hunt/Jupyter test documents/data_reading.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> file_path = os.path.join(os.getcwd(), "data", "TESS_Downloads","TIC_261136679", "mastDownload",
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>                          "TESS","tess2018206045859-s0001-0000000261136679-0120-s",
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>                          "tess2018206045859-s0001-0000000261136679-0120-s_lc.fits")
# ----> <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> lc = lk.read(file_path)
#      <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> print(type(lc))
#      <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> if isinstance(lc, lk.lightcurve.TessLightCurve):
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/lightkurve/io/read.py:97, in read(path_or_url, **kwargs)
#      95     # Raise an explicit FileNotFoundError if file not found
#      96     if "No such file" in str(e):
# ---> 97         raise e
#      98 except Exception as exc2:
#      99     # case unexpected error during detection, e.g., if a file is corrupted such that FITS headers are truncated
#     100     raise LightkurveError(
#     101         f"Unexpected error in detecting the type of the data product: '{type(exc2).__name__}: {exc2}'\n"
#     102         f"{path_or_url}\n"
#     103         "This file may be corrupt due to an interrupted download. "
#     104         "Please remove it from your disk and try again."
#     105     ) from exc2
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/lightkurve/io/read.py:90, in read(path_or_url, **kwargs)
#      88         filetype = detect_filetype(temp)
#      89 else:
# ---> 90     with fits.open(path_or_url) as temp:
#      91         filetype = detect_filetype(temp)
#      92 log.debug("Detected filetype: '{}'.".format(filetype))
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:223, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     220 if not name:
#     221     raise ValueError(f"Empty filename: {name!r}")
# --> 223 return HDUList.fromfile(
#     224     name,
#     225     mode,
#     226     memmap,
#     227     save_backup,
#     228     cache,
#     229     lazy_load_hdus,
#     230     ignore_missing_simple,
#     231     use_fsspec=use_fsspec,
#     232     fsspec_kwargs=fsspec_kwargs,
#     233     decompress_in_memory=decompress_in_memory,
#     234     **kwargs,
#     235 )
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:487, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     468 @classmethod
#     469 def fromfile(
#     470     cls,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     Creates an `HDUList` instance from a file-like object.
#     482
#    (...)
#     485     documentation for details of the parameters accepted by this method).
#     486     """
# --> 487     return cls._readfrom(
#     488         fileobj=fileobj,
#     489         mode=mode,
#     490         memmap=memmap,
#     491         save_backup=save_backup,
#     492         cache=cache,
#     493         ignore_missing_simple=ignore_missing_simple,
#     494         lazy_load_hdus=lazy_load_hdus,
#     495         **kwargs,
#     496     )
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/file.py:651, in _File._open_filename(self, filename, mode, overwrite)
#     648 ext = os.path.splitext(self.name)[1]
#     650 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 651     self._file = open(self.name, IO_FITS_MODES[mode])
#     652     self.close_on_error = True
#     654 # Make certain we're back at the beginning of the file
#     655 # BZ2File does not support seek when the file is open for writing, but
#     656 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/preston/Desktop/Exoplanet-Hunt/Jupyter test documents/data/TESS_Downloads/TIC_261136679/mastDownload/TESS/tess2018206045859-s0001-0000000261136679-0120-s/tess2018206045859-s0001-0000000261136679-0120-s_lc.fits'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/preston/Desktop/Exoplanet-Hunt/Jupyter test documents/data_reading.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> file_path = os.path.join(os.getcwd(), "data", "TESS_Downloads","TIC_261136679", "mastDownload",
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a>                          "TESS","tess2018206045859-s0001-0000000261136679-0120-s",
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a>                          "tess2018206045859-s0001-0000000261136679-0120-s_lc.fits")
# ----> <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> lc = lk.read(file_path)
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> print(type(lc))
#       <a href='vscode-notebook-cell:/home/preston/Desktop/Exoplanet-Hunt/Jupyter%20test%20documents/data_reading.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> if isinstance(lc, lk.lightcurve.TessLightCurve):
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/lightkurve/io/read.py:97, in read(path_or_url, **kwargs)
#      95     # Raise an explicit FileNotFoundError if file not found
#      96     if "No such file" in str(e):
# ---> 97         raise e
#      98 except Exception as exc2:
#      99     # case unexpected error during detection, e.g., if a file is corrupted such that FITS headers are truncated
#     100     raise LightkurveError(
#     101         f"Unexpected error in detecting the type of the data product: '{type(exc2).__name__}: {exc2}'\n"
#     102         f"{path_or_url}\n"
#     103         "This file may be corrupt due to an interrupted download. "
#     104         "Please remove it from your disk and try again."
#     105     ) from exc2
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/lightkurve/io/read.py:90, in read(path_or_url, **kwargs)
#      88         filetype = detect_filetype(temp)
#      89 else:
# ---> 90     with fits.open(path_or_url) as temp:
#      91         filetype = detect_filetype(temp)
#      92 log.debug("Detected filetype: '{}'.".format(filetype))
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:223, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     220 if not name:
#     221     raise ValueError(f"Empty filename: {name!r}")
# --> 223 return HDUList.fromfile(
#     224     name,
#     225     mode,
#     226     memmap,
#     227     save_backup,
#     228     cache,
#     229     lazy_load_hdus,
#     230     ignore_missing_simple,
#     231     use_fsspec=use_fsspec,
#     232     fsspec_kwargs=fsspec_kwargs,
#     233     decompress_in_memory=decompress_in_memory,
#     234     **kwargs,
#     235 )
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:487, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     468 @classmethod
#     469 def fromfile(
#     470     cls,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     Creates an `HDUList` instance from a file-like object.
#     482
#    (...)
#     485     documentation for details of the parameters accepted by this method).
#     486     """
# --> 487     return cls._readfrom(
#     488         fileobj=fileobj,
#     489         mode=mode,
#     490         memmap=memmap,
#     491         save_backup=save_backup,
#     492         cache=cache,
#     493         ignore_missing_simple=ignore_missing_simple,
#     494         lazy_load_hdus=lazy_load_hdus,
#     495         **kwargs,
#     496     )
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/Desktop/Exoplanet-Hunt/exoplanet-env/lib/python3.10/site-packages/astropy/io/fits/file.py:651, in _File._open_filename(self, filename, mode, overwrite)
#     648 ext = os.path.splitext(self.name)[1]
#     650 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 651     self._file = open(self.name, IO_FITS_MODES[mode])
#     652     self.close_on_error = True
#     654 # Make certain we're back at the beginning of the file
#     655 # BZ2File does not support seek when the file is open for writing, but
#     656 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/preston/Desktop/Exoplanet-Hunt/Jupyter test documents/data/TESS_Downloads/TIC_261136679/mastDownload/TESS/tess2018206045859-s0001-0000000261136679-0120-s/tess2018206045859-s0001-0000000261136679-0120-s_lc.fits'
