# %%
import os
import lightkurve as lk
import matplotlib.pyplot as plt

# %%
file_path = os.path.join(os.getcwd(), "Downloaded data", "TIC 261136679","mastDownload","TESS",
    "tess2018206045859-s0001-0000000261136679-0120-s","tess2018206045859-s0001-0000000261136679-0120-s_lc.fits")

lc = lk.read(file_path)
print(type(lc))

if isinstance(lc, lk.lightcurve.TessLightCurve):
    print("lightcurve found.")
    lc.plot()
    plt.show()
# Out:
# <class 'lightkurve.lightcurve.TessLightCurve'>
# lightcurve found.
